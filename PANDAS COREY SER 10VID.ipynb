# %% [markdown]
# ## DATE TIME SERIES DATA AND PLOTTING

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ETH_1H.csv')

# %%
df
# Out:
#                    Date  Symbol    Open    High     Low   Close       Volume
# 0      16/04/2020 00:00  ETHUSD  152.94  152.94  150.39  150.39   650.188125
# 1      15/04/2020 23:00  ETHUSD  155.81  155.81  151.39  152.94  4277.567299
# 2      15/04/2020 22:00  ETHUSD  157.18  157.30  155.32  155.81   106.337279
# 3      15/04/2020 21:00  ETHUSD  158.04  158.31  157.16  157.18    55.244131
# 4      15/04/2020 20:00  ETHUSD  157.10  158.10  156.87  158.04   144.262622
# ...                 ...     ...     ...     ...     ...     ...          ...
# 34492  09/05/2016 17:00  ETHUSD    9.83    9.83    9.48    9.49   329.553213
# 34493  09/05/2016 16:00  ETHUSD    9.99    9.99    9.79    9.83    62.379450
# 34494  09/05/2016 15:00  ETHUSD   10.00   10.00    9.99    9.99    10.973567
# 34495  09/05/2016 14:00  ETHUSD    9.55   10.00    9.55   10.00   235.774075
# 34496  09/05/2016 13:00  ETHUSD    0.00   12.00    0.00    9.55   432.562115
#
# [34497 rows x 7 columns]

# %%
df.shape
# Out:
# (34497, 7)

# %%
df.loc[0,'Date']
# Out:
# '16/04/2020 00:00'

# %%
df.loc[0,'Date'].day_name()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <module>
# ----> 1 df.loc[0,'Date'].day_name()
#
# AttributeError: 'str' object has no attribute 'day_name'

# %%
df['Date'] =pd.to_datetime(df['Date'],format ='%Y-%m-%d %I-%p')

# %%
df['Date']
# Out:
# 0       2020-04-16 00:00:00
# 1       2020-04-15 23:00:00
# 2       2020-04-15 22:00:00
# 3       2020-04-15 21:00:00
# 4       2020-04-15 20:00:00
#                 ...
# 34492   2016-09-05 17:00:00
# 34493   2016-09-05 16:00:00
# 34494   2016-09-05 15:00:00
# 34495   2016-09-05 14:00:00
# 34496   2016-09-05 13:00:00
# Name: Date, Length: 34497, dtype: datetime64[ns]

# %%
df.loc[0,'Date'].day_name()
# Out:
# 'Thursday'

# %%
df['Date'].dt.day_name()
# Out:
# 0         Thursday
# 1        Wednesday
# 2        Wednesday
# 3        Wednesday
# 4        Wednesday
#            ...
# 34492       Monday
# 34493       Monday
# 34494       Monday
# 34495       Monday
# 34496       Monday
# Name: Date, Length: 34497, dtype: object

# %%
df['DayOfWeek'] = df['Date'].dt.day_name()

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close  \
# 0     2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39  150.39
# 1     2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39  152.94
# 2     2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32  155.81
# 3     2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16  157.18
# 4     2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87  158.04
# ...                   ...     ...     ...     ...     ...     ...
# 34492 2016-09-05 17:00:00  ETHUSD    9.83    9.83    9.48    9.49
# 34493 2016-09-05 16:00:00  ETHUSD    9.99    9.99    9.79    9.83
# 34494 2016-09-05 15:00:00  ETHUSD   10.00   10.00    9.99    9.99
# 34495 2016-09-05 14:00:00  ETHUSD    9.55   10.00    9.55   10.00
# 34496 2016-09-05 13:00:00  ETHUSD    0.00   12.00    0.00    9.55
#
#             Volume  DayOfWeek
# 0       650.188125   Thursday
# 1      4277.567299  Wednesday
# 2       106.337279  Wednesday
# 3        55.244131  Wednesday
# ...

# %%
print("TO ACCESS THE EARLIEST DATE OF THE SERIES")
df['Date'].min()
# Out:
# TO ACCESS THE EARLIEST DATE OF THE SERIES
# Timestamp('2016-01-06 00:00:00')

# %%
print('to view the most recent date')
df['Date'].max()
# Out:
# to view the most recent date
# Timestamp('2020-12-04 23:00:00')

# %%
print('substracting the dates it time delta')
df['Date'].max() - df['Date'].min()
# Out:
# substracting the dates it time delta
# Timedelta('1794 days 23:00:00')

# %%
filt = (df['Date'] >= pd.to_datetime('2019-01-01')) & (df['Date'] < pd.to_datetime('2020-01-01'))
df.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close  \
# 2545  2019-12-31 23:00:00  ETHUSD  128.68  128.85  127.82  128.84
# 2546  2019-12-31 22:00:00  ETHUSD  128.40  128.93  127.77  128.68
# 2547  2019-12-31 21:00:00  ETHUSD  127.87  128.41  127.81  128.40
# 2548  2019-12-31 20:00:00  ETHUSD  127.86  128.30  127.86  127.87
# 2549  2019-12-31 19:00:00  ETHUSD  128.78  128.78  127.86  127.86
# ...                   ...     ...     ...     ...     ...     ...
# 11297 2019-01-01 04:00:00  ETHUSD  130.83  133.75  130.83  132.09
# 11298 2019-01-01 03:00:00  ETHUSD  129.79  131.00  129.79  130.83
# 11299 2019-01-01 02:00:00  ETHUSD  130.98  130.98  129.25  129.79
# 11300 2019-01-01 01:00:00  ETHUSD  131.10  131.10  128.72  130.98
# 11301 2019-01-01 00:00:00  ETHUSD  130.80  131.70  130.00  131.10
#
#             Volume DayOfWeek
# 2545    857.650259   Tuesday
# 2546   3050.507350   Tuesday
# 2547    447.680372   Tuesday
# 2548    151.711128   Tuesday
# ...

# %%
df.set_index('Date', inplace=True)

# %%
df
# Out:
#                      Symbol    Open    High     Low   Close       Volume  \
# Date
# 2020-04-16 00:00:00  ETHUSD  152.94  152.94  150.39  150.39   650.188125
# 2020-04-15 23:00:00  ETHUSD  155.81  155.81  151.39  152.94  4277.567299
# 2020-04-15 22:00:00  ETHUSD  157.18  157.30  155.32  155.81   106.337279
# 2020-04-15 21:00:00  ETHUSD  158.04  158.31  157.16  157.18    55.244131
# 2020-04-15 20:00:00  ETHUSD  157.10  158.10  156.87  158.04   144.262622
# ...                     ...     ...     ...     ...     ...          ...
# 2016-09-05 17:00:00  ETHUSD    9.83    9.83    9.48    9.49   329.553213
# 2016-09-05 16:00:00  ETHUSD    9.99    9.99    9.79    9.83    62.379450
# 2016-09-05 15:00:00  ETHUSD   10.00   10.00    9.99    9.99    10.973567
# 2016-09-05 14:00:00  ETHUSD    9.55   10.00    9.55   10.00   235.774075
# 2016-09-05 13:00:00  ETHUSD    0.00   12.00    0.00    9.55   432.562115
#
#                      DayOfWeek
# Date
# 2020-04-16 00:00:00   Thursday
# ...

# %%
df['2019']
# Out:
# C:\Users\SUDHANSU\AppData\Local\Temp\ipykernel_7292\1813439174.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2019']
#                      Symbol    Open    High     Low   Close       Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.68  128.85  127.82  128.84   857.650259
# 2019-12-31 22:00:00  ETHUSD  128.40  128.93  127.77  128.68  3050.507350
# 2019-12-31 21:00:00  ETHUSD  127.87  128.41  127.81  128.40   447.680372
# 2019-12-31 20:00:00  ETHUSD  127.86  128.30  127.86  127.87   151.711128
# 2019-12-31 19:00:00  ETHUSD  128.78  128.78  127.86  127.86  2450.933248
# ...                     ...     ...     ...     ...     ...          ...
# 2019-01-01 04:00:00  ETHUSD  130.83  133.75  130.83  132.09  1035.840465
# 2019-01-01 03:00:00  ETHUSD  129.79  131.00  129.79  130.83  1307.299291
# ...

# %%
df['2020-01':'2020-02']
# Out:
#                      Symbol    Open    High     Low   Close       Volume  \
# Date
# 2020-02-04 23:00:00  ETHUSD  142.64  142.64  140.19  141.56  2435.468835
# 2020-02-04 22:00:00  ETHUSD  142.67  143.03  140.86  142.64  1226.527167
# 2020-02-04 21:00:00  ETHUSD  140.60  142.80  140.19  142.67   916.937424
# 2020-02-04 20:00:00  ETHUSD  141.04  141.16  138.00  140.60  1194.281866
# 2020-02-04 19:00:00  ETHUSD  140.67  142.52  139.70  141.04  2711.122207
# ...                     ...     ...     ...     ...     ...          ...
# 2020-01-01 04:00:00  ETHUSD  129.83  129.96  129.13  129.54  2807.129465
# 2020-01-01 03:00:00  ETHUSD  130.25  130.30  129.42  129.83   883.017780
# 2020-01-01 02:00:00  ETHUSD  129.95  130.58  129.95  130.25   527.921168
# 2020-01-01 01:00:00  ETHUSD  128.11  130.01  128.11  129.95   220.239530
# 2020-01-01 00:00:00  ETHUSD  128.84  128.84  128.07  128.11   526.980282
#
#                      DayOfWeek
# Date
# 2020-02-04 23:00:00    Tuesday
# ...

# %%
df['2020-01':'2020-02']['Close']
# Out:
# Date
# 2020-02-04 23:00:00    141.56
# 2020-02-04 22:00:00    142.64
# 2020-02-04 21:00:00    142.67
# 2020-02-04 20:00:00    140.60
# 2020-02-04 19:00:00    141.04
#                         ...
# 2020-01-01 04:00:00    129.54
# 2020-01-01 03:00:00    129.83
# 2020-01-01 02:00:00    130.25
# 2020-01-01 01:00:00    129.95
# 2020-01-01 00:00:00    128.11
# Name: Close, Length: 1056, dtype: float64

# %%
df['2020-01':'2020-02']['Close'].mean()
# Out:
# 201.7669318181818

# %%
df['2020-01':'2020-02'].head(24)
# Out:
#                      Symbol    Open    High     Low   Close       Volume  \
# Date
# 2020-02-04 23:00:00  ETHUSD  142.64  142.64  140.19  141.56  2435.468835
# 2020-02-04 22:00:00  ETHUSD  142.67  143.03  140.86  142.64  1226.527167
# 2020-02-04 21:00:00  ETHUSD  140.60  142.80  140.19  142.67   916.937424
# 2020-02-04 20:00:00  ETHUSD  141.04  141.16  138.00  140.60  1194.281866
# 2020-02-04 19:00:00  ETHUSD  140.67  142.52  139.70  141.04  2711.122207
# 2020-02-04 18:00:00  ETHUSD  145.60  145.94  140.30  140.67  3021.694805
# 2020-02-04 17:00:00  ETHUSD  143.83  150.32  143.83  145.60  8511.863059
# 2020-02-04 16:00:00  ETHUSD  139.34  143.83  139.34  143.83  2658.744263
# 2020-02-04 15:00:00  ETHUSD  139.40  139.93  138.41  139.34  1101.186499
# 2020-02-04 14:00:00  ETHUSD  136.58  140.00  136.52  139.40  1089.718691
# 2020-02-04 13:00:00  ETHUSD  137.48  137.59  136.43  136.58   767.190254
# 2020-02-04 12:00:00  ETHUSD  137.97  138.92  137.16  137.48  1465.956113
# ...

# %%
df['2020-01']['High']
# Out:
# C:\Users\SUDHANSU\AppData\Local\Temp\ipykernel_7292\3202037033.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2020-01']['High']
# Date
# 2020-01-04 23:00:00    137.33
# 2020-01-04 22:00:00    135.02
# 2020-01-04 21:00:00    132.81
# 2020-01-04 20:00:00    132.99
# 2020-01-04 19:00:00    130.20
#                         ...
# 2020-01-01 04:00:00    129.96
# 2020-01-01 03:00:00    130.30
# 2020-01-01 02:00:00    130.58
# 2020-01-01 01:00:00    130.01
# 2020-01-01 00:00:00    128.84
# Name: High, Length: 552, dtype: float64

# %%
df['2020-01']['High'].max()
# Out:
# C:\Users\SUDHANSU\AppData\Local\Temp\ipykernel_7292\2211633923.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df['2020-01']['High'].max()
# 227.77

# %%
df['High'].resample('D').max()
# Out:
# Date
# 2016-01-06     14.35
# 2016-01-07     12.50
# 2016-01-08     11.89
# 2016-01-09     13.50
# 2016-01-10     13.41
#                ...
# 2020-11-30       NaN
# 2020-12-01    146.57
# 2020-12-02    275.82
# 2020-12-03    195.48
# 2020-12-04    165.37
# Freq: D, Name: High, Length: 1795, dtype: float64

# %%
highs =df['High'].resample('D').max()
highs['2020-01-01']
# Out:
# 132.57

# %%
# %matplotlib inline

# %%
highs.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.resample('W').mean()
# Out:
#                   Open        High         Low       Close       Volume
# Date
# 2016-01-10   12.680250   12.735667   12.614083   12.674667   187.831753
# 2016-01-17    9.646875    9.716667    9.604583    9.635417   141.379699
# 2016-01-24         NaN         NaN         NaN         NaN          NaN
# 2016-01-31         NaN         NaN         NaN         NaN          NaN
# 2016-02-07   12.989167   13.010417   12.969375   12.986250    59.927386
# ...                ...         ...         ...         ...          ...
# 2020-11-08  193.549722  194.822639  192.339583  193.664583  1060.023318
# 2020-11-15         NaN         NaN         NaN         NaN          NaN
# 2020-11-22         NaN         NaN         NaN         NaN          NaN
# 2020-11-29         NaN         NaN         NaN         NaN          NaN
# 2020-12-06  178.958229  180.700000  176.301250  178.415208  2832.136737
#
# [257 rows x 5 columns]

# %%
df.resample('W').agg({'Close':'mean','High':'max','Low':'min','Volume':'sum'})
# Out:
#                  Close    High     Low         Volume
# Date
# 2016-01-10   12.674667   14.35   11.00   22539.810305
# 2016-01-17    9.635417   11.47    8.25    6786.225565
# 2016-01-24         NaN     NaN     NaN       0.000000
# 2016-01-31         NaN     NaN     NaN       0.000000
# 2016-02-07   12.986250   14.13   11.97    2876.514527
# ...                ...     ...     ...            ...
# 2020-11-08  193.664583  239.73  154.25   76321.678869
# 2020-11-15         NaN     NaN     NaN       0.000000
# 2020-11-22         NaN     NaN     NaN       0.000000
# 2020-11-29         NaN     NaN     NaN       0.000000
# 2020-12-06  178.415208  275.82  101.20  271885.126744
#
# [257 rows x 4 columns]
